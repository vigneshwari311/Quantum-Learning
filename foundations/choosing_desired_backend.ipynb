# %%
from qiskit_ibm_runtime.fake_provider import FakeProviderForBackendV2

# %%
provider = FakeProviderForBackendV2()

# %%
available_backends = provider.backends()

print("{0:20} {1:>10}".format("Name", "#Qubits"))
print("{0:20} {1:>10}".format("----", "-------"))

for backend in available_backends:
    config = backend.configuration()
    
    print("{0:20} {1:<10}".format(
        backend.name,
        backend.num_qubits,
        
    ))
# Out:
# Name                    #Qubits
# ----                    -------
# fake_algiers         27
# fake_almaden         20
# fake_armonk          1
# fake_athens          5
# fake_auckland        27
# fake_belem           5
# fake_boeblingen      20
# fake_bogota          5
# fake_brisbane        127
# fake_brooklyn        65
# fake_burlington      5
# fake_cairo           27
# fake_cambridge       28
# fake_casablanca      7
# fake_cusco           127
# fake_essex           5
# fake_fractional      5
# fake_geneva          27
# fake_guadalupe       16
# fake_hanoi           27
# fake_jakarta         7
# fake_johannesburg    20
# fake_kawasaki        127
# fake_kolkata         27
# fake_kyiv            127
# fake_kyoto           127
# fake_lagos           7
# fake_lima            5
# fake_london          5
# fake_manhattan       65
# fake_manila          5
# fake_melbourne       15
# fake_montreal        27
# fake_mumbai          27
# fake_nairobi         7
# fake_osaka           127
# fake_oslo            7
# fake_ourense         5
# fake_paris           27
# fake_peekskill       27
# fake_perth           7
# fake_prague          33
# fake_poughkeepsie    20
# fake_quebec          127
# fake_quito           5
# fake_rochester       53
# fake_rome            5
# fake_santiago        5
# fake_sherbrooke      127
# fake_singapore       20
# fake_sydney          27
# fake_torino          133
# fake_toronto         27
# fake_valencia        5
# fake_vigo            5
# fake_washington      127
# fake_yorktown        5

# %% [markdown]
# ### Filter only 5 qubits fakebackend

# %%
fake_backend_5_qubits = [b for b in available_backends if b.num_qubits == 5]

# %%
print(*(b.name for b in fake_backend_5_qubits), sep='\n')
# Out:
# fake_athens
# fake_belem
# fake_bogota
# fake_burlington
# fake_essex
# fake_fractional
# fake_lima
# fake_london
# fake_manila
# fake_ourense
# fake_quito
# fake_rome
# fake_santiago
# fake_valencia
# fake_vigo
# fake_yorktown

# %%
for i in range(fake_backend_5_qubits[0].num_qubits):
    
    props = fake_backend_5_qubits[0].target.qubit_properties[i]
    
    print(f"\nOubits {i}:")
    
    print("T1 :",props.t1)
    print("T2 :",props.t2)
    print("Frequency :",props.frequency)
# Out:
# Oubits 0:
# T1 : 6.348783021708388e-05
# T2 : 0.00011223245535599809
# Frequency : 5175383639.513607
#
# Oubits 1:
# T1 : 7.309351830154399e-05
# T2 : 0.00012683382141649016
# Frequency : 5267216864.382969
#
# Oubits 2:
# T1 : 3.291818023387998e-05
# T2 : 5.980643883454234e-05
# Frequency : 5052402469.794663
#
# Oubits 3:
# T1 : 4.951084562967435e-05
# T2 : 2.055130827115546e-05
# Frequency : 4855916030.466884
#
# Oubits 4:
# T1 : 0.00011144095341923331
# T2 : 0.00016876253828389227
# Frequency : 5118554567.140891

# %%
# Out:
# Using Fake Backend: fake_manila
# Gate CX[4, 3]: Error = 0.57%
# Gate CX[3, 4]: Error = 0.57%
# Gate CX[2, 3]: Error = 1.135%
# Gate CX[3, 2]: Error = 1.135%
# Gate CX[1, 2]: Error = 1.394%
# Gate CX[2, 1]: Error = 1.394%
# Gate CX[0, 1]: Error = 0.883%
# Gate CX[1, 0]: Error = 0.883%
#
# Best CX: [4, 3] with 0.57% error
# Worst CX: [2, 1] with 1.394% error
# Running simulations...
